# %%
import pandas as pd

df = pd.read_csv("cleaned_global_ecommerce_sales.csv")
df.head()
# Out:
#     order_id  order_date   customer_name customer_segment        country  \
# 0  ORD-11121  2023-01-02    Karen Suzuki        Corporate  United States
# 1  ORD-11244  2023-01-02  John Johansson        Corporate          Spain
# 2  ORD-10325  2023-01-03  Jessica Garcia         Consumer         Mexico
# 3  ORD-10467  2023-01-03    Clara Taylor        Corporate          Italy
# 4  ORD-11746  2023-01-05   Fatima Suzuki         Consumer         Mexico
#
#           region product_category                   product_name  quantity  \
# 0  North America       Technology  Wireless Bluetooth Headphones         3
# 1         Europe       Technology     Mechanical Gaming Keyboard         4
# 2  North America  Office Supplies     Binder Clips Assorted 48pc         2
# 3         Europe       Technology                Webcam HD 1080p         2
# 4  North America        Furniture               Bookshelf 5-Tier         1
#
#    unit_price  discount_percent  total_sales  shipping_cost  profit  \
# 0       99.43                 0       298.29           9.31  124.92
# 1       97.93                20       313.38          14.31   83.62
# 2       10.74                 0        21.48           8.12    3.69
# 3       61.86                15       105.16          10.79   26.32
# 4       61.93                10        55.74           5.88   12.70
#
#      payment_method
# 0  Cash on Delivery
# 1  Cash on Delivery
# 2       Credit Card
# 3            PayPal
# 4            PayPal

# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect("ecommerce.db")

# %%
df.to_sql("sales", conn, if_exists="replace", index=False)
# Out:
# 1810

# %%
pd.read_sql("SELECT * FROM sales LIMIT 5;", conn)
# Out:
#     order_id  order_date   customer_name customer_segment        country  \
# 0  ORD-11121  2023-01-02    Karen Suzuki        Corporate  United States
# 1  ORD-11244  2023-01-02  John Johansson        Corporate          Spain
# 2  ORD-10325  2023-01-03  Jessica Garcia         Consumer         Mexico
# 3  ORD-10467  2023-01-03    Clara Taylor        Corporate          Italy
# 4  ORD-11746  2023-01-05   Fatima Suzuki         Consumer         Mexico
#
#           region product_category                   product_name  quantity  \
# 0  North America       Technology  Wireless Bluetooth Headphones         3
# 1         Europe       Technology     Mechanical Gaming Keyboard         4
# 2  North America  Office Supplies     Binder Clips Assorted 48pc         2
# 3         Europe       Technology                Webcam HD 1080p         2
# 4  North America        Furniture               Bookshelf 5-Tier         1
#
#    unit_price  discount_percent  total_sales  shipping_cost  profit  \
# 0       99.43                 0       298.29           9.31  124.92
# 1       97.93                20       313.38          14.31   83.62
# 2       10.74                 0        21.48           8.12    3.69
# 3       61.86                15       105.16          10.79   26.32
# 4       61.93                10        55.74           5.88   12.70
#
#      payment_method
# 0  Cash on Delivery
# 1  Cash on Delivery
# 2       Credit Card
# 3            PayPal
# 4            PayPal

# %% [markdown]
# SELECT

# %%
query = """
SELECT * FROM sales;
"""

pd.read_sql(query, conn)
# Out:
#        order_id  order_date      customer_name customer_segment  \
# 0     ORD-11121  2023-01-02       Karen Suzuki        Corporate
# 1     ORD-11244  2023-01-02     John Johansson        Corporate
# 2     ORD-10325  2023-01-03     Jessica Garcia         Consumer
# 3     ORD-10467  2023-01-03       Clara Taylor        Corporate
# 4     ORD-11746  2023-01-05      Fatima Suzuki         Consumer
# ...         ...         ...                ...              ...
# 1805  ORD-11814  2025-12-30  Jennifer Oliveira         Consumer
# 1806  ORD-10823  2025-12-31      Linda Nilsson         Consumer
# 1807  ORD-11148  2025-12-31      Barbara Jones         Consumer
# 1808  ORD-11519  2025-12-31       Maria Suzuki      Home Office
# 1809  ORD-11701  2025-12-31        Susan Russo      Home Office
#
#             country         region        product_category  \
# 0     United States  North America              Technology
# 1             Spain         Europe              Technology
# 2            Mexico  North America         Office Supplies
# 3             Italy         Europe              Technology
# 4            Mexico  North America               Furniture
# ...             ...            ...                     ...
# 1805          India   Asia Pacific               Furniture
# 1806         France         Europe               Furniture
# 1807          Spain         Europe              Technology
# 1808          Spain         Europe  Clothing & Accessories
# 1809    South Korea   Asia Pacific  Clothing & Accessories
#
#                        product_name  quantity  unit_price  discount_percent  \
# 0     Wireless Bluetooth Headphones         3       99.43                 0
# 1        Mechanical Gaming Keyboard         4       97.93                20
# 2        Binder Clips Assorted 48pc         2       10.74                 0
# 3                   Webcam HD 1080p         2       61.86                15
# 4                  Bookshelf 5-Tier         1       61.93                10
# ...                             ...       ...         ...               ...
# 1805        Filing Cabinet 3-Drawer         1      177.90                10
# 1806         Folding Table Portable         5      104.73                 0
# 1807                Webcam HD 1080p         6       31.79                15
# 1808      Sports Water Bottle 750ml         5        9.50                 5
# 1809      Sports Water Bottle 750ml        11       28.27                 0
#
#       total_sales  shipping_cost  profit    payment_method
# 0          298.29           9.31  124.92  Cash on Delivery
# 1          313.38          14.31   83.62  Cash on Delivery
# 2           21.48           8.12    3.69       Credit Card
# 3          105.16          10.79   26.32            PayPal
# 4           55.74           5.88   12.70            PayPal
# ...           ...            ...     ...               ...
# 1805       160.11          10.23   43.14            PayPal
# 1806       523.65          19.10  190.36            PayPal
# 1807       162.13          15.19   42.03     Bank Transfer
# 1808        45.12          14.25    7.12       Credit Card
# 1809       310.97          36.23  119.26       Credit Card
#
# [1810 rows x 15 columns]

# %% [markdown]
# WHERE

# %%
query = """
SELECT * FROM sales
WHERE total_sales > 500;
"""

pd.read_sql(query, conn)
# Out:
#      order_id  order_date     customer_name customer_segment        country  \
# 0   ORD-10402  2023-01-14     Jamal Schmidt         Consumer         Mexico
# 1   ORD-10594  2023-02-21        Ayumi Khan         Consumer  United States
# 2   ORD-10915  2023-03-08      Ahmed Harris         Consumer         Brazil
# 3   ORD-10676  2023-03-17          Wei Chen         Consumer   Saudi Arabia
# 4   ORD-10071  2023-04-05    Richard Müller         Consumer  United States
# ..        ...         ...               ...              ...            ...
# 62  ORD-11608  2025-11-01     Isabella Sato         Consumer      Argentina
# 63  ORD-11256  2025-11-03         Ivan Sato         Consumer          Spain
# 64  ORD-11940  2025-11-03      Hanna Hassan      Home Office         France
# 65  ORD-11693  2025-12-10  Carlos Rodriguez        Corporate         Brazil
# 66  ORD-10823  2025-12-31     Linda Nilsson         Consumer         France
#
#                   region        product_category                product_name  \
# 0          North America               Furniture      Folding Table Portable
# 1          North America              Technology         Smart LED Desk Lamp
# 2          South America               Furniture   Floating Wall Shelves Set
# 3   Middle East & Africa              Technology  Mechanical Gaming Keyboard
# 4          North America               Furniture      Ergonomic Office Chair
# ..                   ...                     ...                         ...
# 62         South America  Clothing & Accessories         Travel Backpack 30L
# 63                Europe               Furniture        Corner L-Shaped Desk
# 64                Europe              Technology   Portable External SSD 1TB
# 65         South America               Furniture            Bookshelf 5-Tier
# 66                Europe               Furniture      Folding Table Portable
#
#     quantity  unit_price  discount_percent  total_sales  shipping_cost  \
# 0          6       96.58                 0       579.48          10.22
# 1          8       72.89                 0       583.12          14.27
# 2          6       99.69                 0       598.14          18.01
# 3          3      174.46                 0       523.38          14.65
# 4          2      252.68                 0       505.36           8.12
# ..       ...         ...               ...          ...            ...
# 62         6       92.98                 0       557.88          18.67
# 63         2      297.84                15       506.33           8.55
# 64         6      110.54                10       596.92          21.12
# 65         3      194.57                 0       583.71          13.80
# 66         5      104.73                 0       523.65          19.10
#
#     profit payment_method
# 0   221.57    Credit Card
# 1   248.13    Credit Card
# 2   221.25    Credit Card
# 3   220.87    Credit Card
# 4   194.02         PayPal
# ..     ...            ...
# 62  260.27         PayPal
# 63  140.37  Bank Transfer
# 64  211.02         PayPal
# 65  219.68    Credit Card
# 66  190.36         PayPal
#
# [67 rows x 15 columns]

# %% [markdown]
# ORDER BY

# %%
query = """
SELECT * FROM sales
ORDER BY total_sales DESC;
"""

pd.read_sql(query, conn)
# Out:
#        order_id  order_date      customer_name customer_segment  \
# 0     ORD-11422  2023-09-03        David Clark         Consumer
# 1     ORD-10975  2025-01-04      Oscar Nilsson         Consumer
# 2     ORD-11795  2023-09-14        Ali Johnson        Corporate
# 3     ORD-10661  2023-06-29       Olga Nilsson         Consumer
# 4     ORD-11541  2025-09-23        Sarah Weber      Home Office
# ...         ...         ...                ...              ...
# 1805  ORD-11430  2023-02-04     Karen Martinez      Home Office
# 1806  ORD-11269  2024-10-17   Sophie Johansson        Corporate
# 1807  ORD-10407  2024-04-21   Isabella Laurent        Corporate
# 1808  ORD-11662  2025-06-07  Jennifer Thompson        Corporate
# 1809  ORD-11001  2025-02-20   Isabella Jackson        Corporate
#
#             country                region product_category  \
# 0           Germany                Europe        Furniture
# 1            France                Europe        Furniture
# 2            Mexico         North America        Furniture
# 3            Canada         North America       Technology
# 4     United States         North America        Furniture
# ...             ...                   ...              ...
# 1805       Colombia         South America  Office Supplies
# 1806   Saudi Arabia  Middle East & Africa  Office Supplies
# 1807        Germany                Europe  Office Supplies
# 1808         Mexico         North America  Office Supplies
# 1809          Japan          Asia Pacific  Office Supplies
#
#                         product_name  quantity  unit_price  discount_percent  \
# 0             Folding Table Portable        10       67.10                10
# 1            Filing Cabinet 3-Drawer         5      127.03                 5
# 2                 Monitor Riser Wood        14       61.54                30
# 3                    Webcam HD 1080p         9       74.43                10
# 4               Mesh Back Task Chair         6      118.21                15
# ...                              ...       ...         ...               ...
# 1805           Paper Clips Box 500pc         1        4.78                10
# 1806           Paper Clips Box 500pc         1        4.87                15
# 1807  Sticky Notes Multicolor 6-Pack         1        4.02                15
# 1808           Paper Clips Box 500pc         1        3.44                25
# 1809           Paper Clips Box 500pc         1        3.03                20
#
#       total_sales  shipping_cost  profit    payment_method
# 0          603.90          14.47  186.83  Cash on Delivery
# 1          603.39          16.49  205.81            PayPal
# 2          603.09          33.58   52.57       Credit Card
# 3          602.88          11.59  222.86       Credit Card
# 4          602.87          11.16  166.15       Credit Card
# ...           ...            ...     ...               ...
# 1805         4.30          11.84   -9.69     Bank Transfer
# 1806         4.14          12.43  -10.48     Bank Transfer
# 1807         3.42           7.74   -6.13     Bank Transfer
# 1808         2.58           6.69   -5.66       Credit Card
# 1809         2.42          11.16  -10.10  Cash on Delivery
#
# [1810 rows x 15 columns]

# %% [markdown]
# LIMIT

# %%
query = """
SELECT * FROM sales
LIMIT 10;
"""

pd.read_sql(query, conn)
# Out:
#     order_id  order_date    customer_name customer_segment        country  \
# 0  ORD-11121  2023-01-02     Karen Suzuki        Corporate  United States
# 1  ORD-11244  2023-01-02   John Johansson        Corporate          Spain
# 2  ORD-10325  2023-01-03   Jessica Garcia         Consumer         Mexico
# 3  ORD-10467  2023-01-03     Clara Taylor        Corporate          Italy
# 4  ORD-11746  2023-01-05    Fatima Suzuki         Consumer         Mexico
# 5  ORD-11162  2023-01-06  Felix Rodriguez      Home Office  United States
# 6  ORD-11271  2023-01-06    Ayumi Ferrari      Home Office        Nigeria
# 7  ORD-10847  2023-01-07    Ali Rodriguez         Consumer   Saudi Arabia
# 8  ORD-10446  2023-01-08     Raj Martinez        Corporate       Colombia
# 9  ORD-11499  2023-01-08      Kenji Rossi        Corporate          Spain
#
#                  region        product_category  \
# 0         North America              Technology
# 1                Europe              Technology
# 2         North America         Office Supplies
# 3                Europe              Technology
# 4         North America               Furniture
# 5         North America         Office Supplies
# 6  Middle East & Africa              Technology
# 7  Middle East & Africa               Furniture
# 8         South America  Clothing & Accessories
# 9                Europe         Office Supplies
#
#                     product_name  quantity  unit_price  discount_percent  \
# 0  Wireless Bluetooth Headphones         3       99.43                 0
# 1     Mechanical Gaming Keyboard         4       97.93                20
# 2     Binder Clips Assorted 48pc         2       10.74                 0
# 3                Webcam HD 1080p         2       61.86                15
# 4               Bookshelf 5-Tier         1       61.93                10
# 5        Premium Notebook Set A5         2       15.03                 5
# 6        Laptop Stand Adjustable         2       33.91                10
# 7         Folding Table Portable         1       58.77                 5
# 8      Leather Wallet Minimalist         2       38.91                15
# 9          Paper Clips Box 500pc         3        7.80                10
#
#    total_sales  shipping_cost  profit    payment_method
# 0       298.29           9.31  124.92  Cash on Delivery
# 1       313.38          14.31   83.62  Cash on Delivery
# 2        21.48           8.12    3.69       Credit Card
# 3       105.16          10.79   26.32            PayPal
# 4        55.74           5.88   12.70            PayPal
# 5        28.56           6.59    8.44            PayPal
# 6        61.04          14.38    9.36     Bank Transfer
# 7        55.83          12.03    8.54       Credit Card
# 8        66.15          14.25   12.99       Credit Card
# 9        21.06          12.61   -2.08  Cash on Delivery

# %% [markdown]
# COUNT

# %%
query = """
SELECT COUNT(*) AS total_records
FROM sales;
"""

pd.read_sql(query, conn)
# Out:
#    total_records
# 0           1810

# %% [markdown]
# SUM

# %%
query = """
SELECT SUM(total_sales) AS total_sales
FROM sales;
"""

pd.read_sql(query, conn)
# Out:
#    total_sales
# 0    261284.78

# %% [markdown]
# AVERAGE

# %%
query = """
SELECT AVG(total_sales) AS average_sales
FROM sales;
"""

pd.read_sql(query, conn)
# Out:
#    average_sales
# 0     144.356232

# %% [markdown]
# GROUP BY

# %%
query = """
SELECT product_category,
SUM(total_sales) AS total_sales
FROM sales
GROUP BY product_category;
"""

pd.read_sql(query, conn)
# Out:
#          product_category  total_sales
# 0  Clothing & Accessories     57730.36
# 1               Furniture     90424.83
# 2         Office Supplies     19390.81
# 3              Technology     93738.78

# %%
df.columns.tolist()
# Out:
# ['order_id',
#  'order_date',
#  'customer_name',
#  'customer_segment',
#  'country',
#  'region',
#  'product_category',
#  'product_name',
#  'quantity',
#  'unit_price',
#  'discount_percent',
#  'total_sales',
#  'shipping_cost',
#  'profit',
#  'payment_method']
